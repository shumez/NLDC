# %% [markdown]
# # 7 Limit Cycles
# ---

# %% [markdown]
# *Overview*
#
# - [7.0 Introduction](#7.0-Introduction)
#
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

c = ['#1f77b4', 
     '#ff7f0e', 
     '#2ca02c', 
     '#d62728', 
     '#9467bd', 
     '#8c564b', 
     '#e377c2', 
     '#7f7f7f', 
     '#bcbd22', 
     '#17becf']

l = ['-', '--', '-.', ':']
m = ['o', 'x', 's']

"""
figname = '7__'
plt.savefig(('img/fig_%s.png' % figname), dpi=None, facecolor='w', edgecolor='w',
            orientation='portrait', papertype=None, format='png',
            transparent=False, bbox_inches=None, pad_inches=0.1,
            frameon=None)
"""

"""
$$\begin{align*}
& \quad\quad (7.)
\end{align*}$$
"""
# Out:
# '\n$$\x08egin{align*}\n& \\quad\\quad (5.)\n\\end{align*}$$\n'

# %% [markdown]
# ## 7.0 Introduction
# ---

# %% [markdown]
# **limit cycle**
# - isolated closed trajectory

# %% [markdown]
# - stable / attracting:
#     - all neiboring trajectories approach the limit cycle
# - unstable
# - half-stable

# %%
A = np.array([[0, -1], [1,0]])

def x_dot(x, y, A):
    x_ = A[0,0]*x + A[0,1]*y
    return x_

def y_dot(x, y, A):
    y_ = A[1,0]*x + A[1,1]*y
    return y_

def speed(x, y, A):
    s = x_dot(x, y, A)**2 + y_dot(x, y, A)**2
    s = np.sqrt(s)
    return s

def X_dot(X, A):
    X_ = np.dot(A, X)
    return X_

x, y = np.linspace(-2, 2, 10), np.linspace(-2, 2, 10)
x, y = np.meshgrid(x, y)

plt.figure(figsize=(5, 5))
figname='7_0_2'

plt.streamplot(x, y, x_dot(x, y, A), y_dot(x, y, A), 
               density=.5,
               color=speed(x, y, A), cmap='viridis')


plt.grid(True)
# plt.tight_layout()

plt.savefig(('img/fig_%s.png' % figname), dpi=None, facecolor='w', edgecolor='w',
            orientation='portrait', papertype=None, format='png',
            transparent=False, bbox_inches=None, pad_inches=0.1,
            frameon=None)
plt.show()

# %% [markdown]
# ## 7.1 Examples
# ---

# %% [markdown]
# ### Example 7.1.1
# ### A Simple Limit Cycle

# %% [markdown]
# consider
#
# $$\begin{align*}
# \dot{r} = r(1 - r^2), & \quad \dot{\theta} = 1
# & \quad\quad (7.1.1)
# \end{align*}$$
#
# where $r ≥ 0$

# %%
def r_dot(r):
    r_ = r * (1 - r**2)
    return r_

r = np.linspace(0, 1.2, 100)
r_vec = np.linspace(0, 1.2, 10)

plt.figure(figsize=(5, 5))
figname = '7_1_1'

plt.plot(r, r_dot(r))
plt.quiver(r_vec, 0, r_dot(r_vec), 0, color=c[0], alpha=.7)

plt.xlabel(r'$r$')
plt.ylabel(r'$\dot{r}$')
plt.grid(True)

plt.savefig(('img/fig_%s.png' % figname), dpi=None, facecolor='w', edgecolor='w',
            orientation='portrait', papertype=None, format='png',
            transparent=False, bbox_inches=None, pad_inches=0.1,
            frameon=None)

plt.show()

# %%
def r_dot(r, theta):
    r_ = r * (1 - r**2)
    return r_

def theta_dot(r, theta):
    theta_ = 1
    return theta_

r = np.linspace(0.01, 1.2, 10)
theta = np.linspace(-np.pi, np.pi, 10)
r, theta = np.meshgrid(r, theta)


x = np.cos(theta) * r
y = np.sin(theta) * r

x_dot = -np.sin(theta)*np.cos(theta_dot(r, theta))*r + np.cos(theta) * r_dot(r, theta)
y_dot = np.cos(theta)*np.sin(theta_dot(r, theta))*r + np.sin(theta) * r_dot(r, theta)

figname = '7_1_2'
plt.figure(figsize=(5, 5))

plt.streamplot(x, y, x_dot, y_dot)

# plt.xlabel(r'$x$')
# plt.ylabel(r'$y$')
# plt.grid(True)

# plt.savefig(('img/fig_%s.png' % figname), dpi=None, facecolor='w', edgecolor='w',
#             orientation='portrait', papertype=None, format='png',
#             transparent=False, bbox_inches=None, pad_inches=0.1,
#             frameon=None)

plt.show()

# print(np.shape(x))
# print(np.shape(y))
# print(x_dot)
# print(np.shape(y_dot))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ea69e5e344d7> in <module>()
#      21 figname = '7_1_2'
#      22
# ---> 23 plt.streamplot(x, y, x_dot, y_dot)
#      24
#      25 # plt.xlabel(r'$x$')
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/matplotlib/pyplot.py in streamplot(x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction, hold, data)
#    3540                             maxlength=maxlength,
#    3541                             integration_direction=integration_direction,
# -> 3542                             data=data)
#    3543     finally:
#    3544         ax._hold = washold
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/matplotlib/axes/_axes.py in streamplot(self, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction)
#    4619             zorder=zorder,
#    4620             maxlength=maxlength,
# -> 4621             integration_direction=integration_direction)
#    4622         return stream_container
#    4623     streamplot.__doc__ = mstream.streamplot.__doc__
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/matplotlib/streamplot.py in streamplot(axes, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction)
#      81
#      82     """
# ---> 83     grid = Grid(x, y)
#      84     mask = StreamMask(density)
#      85     dmap = DomainMap(grid, mask)
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/matplotlib/streamplot.py in __init__(self, x, y)
#     314             x_row = x[0, :]
#     315             if not np.allclose(x_row, x):
# --> 316                 raise ValueError("The rows of 'x' must be equal")
#     317             x = x_row
#     318         else:
#
# ValueError: The rows of 'x' must be equal

# %% [markdown]
# ---
# *Overview*
#
# - [7.0 Introduction](#7.0-Introduction)
# - [7.1 Examples](#7.1-Examples)
#     - [Example 7.1.1](#Example-7.1.1)
